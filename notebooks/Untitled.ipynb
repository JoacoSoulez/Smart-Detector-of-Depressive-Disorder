# %%
import pandas as pd

# %%
pd.read_csv('..\..\transcriptions\302_TRANSCRIPT.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1864/3662439989.py in <module>
# ----> 1 pd.read_csv('..\..\transcriptions\302_TRANSCRIPT.csv')
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
